# %% [markdown]
# # **EVENTS CHECK & CONTEXT**

# %%
import pandas as pd

events = pd.read_csv(r"C:\Git projects\ufc_ml\ufc_data\ufc_events.csv")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

events["event_date"] = pd.to_datetime(events["event_date"], errors="coerce")

events["event_date"] = events["event_date"].dt.strftime("%m/%d/%Y")


print(events.columns)
events.head(3)
# Out:
# Index(['event_name', 'event_date', 'event_location', 'event_url', 'fight_url',
#        'fighter1', 'fighter1_url', 'fighter2', 'fighter2_url', 'result_raw',
#        'winner', 'kd_1', 'kd_2', 'str_1', 'str_2', 'td_1', 'td_2', 'sub_1',
#        'sub_2', 'weight_class', 'method', 'method_detail', 'round', 'time'],
#       dtype='str')
#                            event_name  event_date    event_location  \
# 0  UFC Fight Night: Fiziev vs. Torres  06/27/2026  Baku, Azerbaijan
# 1  UFC Fight Night: Fiziev vs. Torres  06/27/2026  Baku, Azerbaijan
# 2  UFC Fight Night: Fiziev vs. Torres  06/27/2026  Baku, Azerbaijan
#
#                                             event_url  \
# 0  http://ufcstats.com/event-details/31e1ea6fe6b682f8
# 1  http://ufcstats.com/event-details/31e1ea6fe6b682f8
# 2  http://ufcstats.com/event-details/31e1ea6fe6b682f8
#
#                                             fight_url         fighter1  \
# 0  http://ufcstats.com/fight-details/c13dc0cccef263f7    Rafael Fiziev
# 1  http://ufcstats.com/fight-details/012c307c9d446c4d  Shara Magomedov
# 2  http://ufcstats.com/fight-details/809814f03ff3140c   Matheus Camilo
#
#                                            fighter1_url        fighter2  \
# 0  http://ufcstats.com/fighter-details/c814b4c899793af6   Manuel Torres
# 1  http://ufcstats.com/fighter-details/06734ca9d88dec3a  Michel Pereira
# 2  http://ufcstats.com/fighter-details/72f890c5d421e705  Nazim Sadykhov
#
#                                            fighter2_url result_raw  \
# 0  http://ufcstats.com/fighter-details/2e7878927067fdca        win
# 1  http://ufcstats.com/fighter-details/595db60957de51d3        win
# 2  http://ufcstats.com/fighter-details/ff62013d2fce6d13        win
#
#             winner  kd_1  kd_2  str_1  str_2  td_1  td_2  sub_1  sub_2  \
# 0    Rafael Fiziev     1     0     25     22     2     0      0      0
# 1  Shara Magomedov     0     1     52     35     0     0      0      0
# 2   Matheus Camilo     1     0      4      0     0     0      0      0
#
#    weight_class  method method_detail  round  time
# 0   Lightweight  KO/TKO       Punches      2  0:15
# 1  Middleweight   U-DEC           NaN      3  5:00
# 2   Lightweight  KO/TKO         Punch      1  1:31

# %% [markdown]
# ## CATEGORICAL COLUMNS CHECK

# %%
#result_raw weight_class	method	method_detail	round	
print(f"Result types ({(events['result_raw'].nunique())}): {list(events['result_raw'].unique())}")
print(f"Weight types ({(events['weight_class'].nunique())}): {list(events['weight_class'].unique())}")
print(f"Method types ({(events['method'].nunique())}): {list(events['method'].unique())}")
print(f"Method Detail types ({(events['method_detail'].nunique())}): {list(events['method_detail'].unique())}")
print(f"Round types ({(events['round'].nunique())}): {list(events['round'].unique())}")
print(f"Latest Event: {(events['event_date'].max())}")
print(f"Earliest Event: {(events['event_date'].min())}")
print(f"\n          NULL VALUES\n{events.isna().sum()}")
# Out:
# Result types (3): ['win', 'nc/nc', 'draw/draw']
# Weight types (13): ['Lightweight', 'Middleweight', 'Flyweight', 'Welterweight', 'Light Heavyweight', 'Featherweight', 'Bantamweight', "Women's Bantamweight", 'Heavyweight', 'Catch Weight', "Women's Flyweight", "Women's Strawweight", "Women's Featherweight"]
# Method types (8): ['KO/TKO', 'U-DEC', 'SUB', 'S-DEC', 'CNC', 'M-DEC', 'Overturned', 'DQ']
# Method Detail types (32): ['Punches', nan, 'Punch', 'Suloev Stretch', 'Guillotine Choke', 'Rear Naked Choke', 'Arm Triangle', 'Twister', 'Elbows', 'Armbar', 'Kick', 'Knee', 'Calf Slicer', 'Heel Hook', "D'Arce Choke", 'Anaconda Choke', 'Knees', 'Spinning Back Kick', 'Neck Crank', 'Spinning Back Fist', 'Kimura', 'Elbow', 'Ezekiel Choke', 'Spinning Back Elbow', 'Triangle Choke', 'Slam', 'Keylock', 'Flying Knee', 'Triangle Armbar', 'Kicks', 'Other - Lock', 'Kneebar', 'Inverted Triangle']
# Round types (5): [2, 3, 1, 4, 5]
# Latest Event: 12/17/2022
# Earliest Event: 01/11/2025
#
#           NULL VALUES
# event_name          0
# event_date          0
# event_location      0
# event_url           0
# fight_url           0
# fighter1            0
# fighter1_url        0
# fighter2            0
# fighter2_url        0
# result_raw          0
# winner             32
# kd_1                0
# kd_2                0
# str_1               0
# str_2               0
# td_1                0
# td_2                0
# sub_1               0
# sub_2               0
# weight_class        0
# method              0
# method_detail     969
# round               0
# time                0
# dtype: int64

# %% [markdown]
# ### CHECK OF NULL VALUES

# %%
null_detail = events[events["method_detail"].isnull()]
print(f"Method types ({(null_detail['method'].nunique())}): {list(null_detail['method'].unique())}")
null_detail.head(3)
# Out:
# Method types (7): ['U-DEC', 'S-DEC', 'KO/TKO', 'CNC', 'M-DEC', 'Overturned', 'DQ']
#                            event_name  event_date    event_location  \
# 1  UFC Fight Night: Fiziev vs. Torres  06/27/2026  Baku, Azerbaijan
# 4  UFC Fight Night: Fiziev vs. Torres  06/27/2026  Baku, Azerbaijan
# 6  UFC Fight Night: Fiziev vs. Torres  06/27/2026  Baku, Azerbaijan
#
#                                             event_url  \
# 1  http://ufcstats.com/event-details/31e1ea6fe6b682f8
# 4  http://ufcstats.com/event-details/31e1ea6fe6b682f8
# 6  http://ufcstats.com/event-details/31e1ea6fe6b682f8
#
#                                             fight_url         fighter1  \
# 1  http://ufcstats.com/fight-details/012c307c9d446c4d  Shara Magomedov
# 4  http://ufcstats.com/fight-details/d83294b031502177  Ikram Aliskerov
# 6  http://ufcstats.com/fight-details/6a35ff33b8597904   Farman Hasanov
#
#                                            fighter1_url         fighter2  \
# 1  http://ufcstats.com/fighter-details/06734ca9d88dec3a   Michel Pereira
# 4  http://ufcstats.com/fighter-details/b07aed698fba8624  Brunno Ferreira
# 6  http://ufcstats.com/fighter-details/c88f8a9c1ea7165d       Eric Nolan
#
#                                            fighter2_url result_raw  \
# 1  http://ufcstats.com/fighter-details/595db60957de51d3        win
# 4  http://ufcstats.com/fighter-details/1e719d4b676dc19a        win
# 6  http://ufcstats.com/fighter-details/64b12fe31be7560c        win
#
#             winner  kd_1  kd_2  str_1  str_2  td_1  td_2  sub_1  sub_2  \
# 1  Shara Magomedov     0     1     52     35     0     0      0      0
# 4  Ikram Aliskerov     0     0     47     19     5     0      1      0
# 6   Farman Hasanov     0     0     21     15    17     0      0      0
#
#    weight_class method method_detail  round  time
# 1  Middleweight  U-DEC           NaN      3  5:00
# 4  Middleweight  U-DEC           NaN      3  5:00
# 6  Welterweight  U-DEC           NaN      3  5:00

# %%
null_winner = events[events["winner"].isnull() ]#& (events["result_raw"]=="nc/nc")]
print(f"Method types ({(null_winner['method'].nunique())}): {list(null_winner['method'].unique())}")
print(f"Result types ({(null_winner['result_raw'].nunique())}): {list(null_winner['result_raw'].unique())}")
null_winner.head(3)
# Out:
# Method types (5): ['CNC', 'M-DEC', 'Overturned', 'U-DEC', 'S-DEC']
# Result types (2): ['nc/nc', 'draw/draw']
#                                event_name  event_date  \
# 49   UFC Fight Night: Song vs. Figueiredo  05/30/2026
# 119     UFC Fight Night: Burns vs. Malott  04/18/2026
# 130         UFC 327: Prochazka vs. Ulberg  04/11/2026
#
#                  event_location  \
# 49                 Macau, China
# 119  Winnipeg, Manitoba, Canada
# 130         Miami, Florida, USA
#
#                                               event_url  \
# 49   http://ufcstats.com/event-details/1e75e6c9de99fa76
# 119  http://ufcstats.com/event-details/c3ac8d0da7b05772
# 130  http://ufcstats.com/event-details/f3eb664db7fb1df3
#
#                                               fight_url        fighter1  \
# 49   http://ufcstats.com/fight-details/7e8749cbf32ef1f8      Alex Perez
# 119  http://ufcstats.com/fight-details/552f7cdaf93e1055  John Castaneda
# 130  http://ufcstats.com/fight-details/81d20c833e9a76eb   Chris Padilla
#
#                                              fighter1_url         fighter2  \
# 49   http://ufcstats.com/fighter-details/ab2b4ff41d6ebe0f       Sumudaerji
# 119  http://ufcstats.com/fighter-details/5fa2974cbd18e05c    Mark Vologdin
# 130  http://ufcstats.com/fighter-details/06626b6287e1ae1e  MarQuel Mederos
#
#                                              fighter2_url result_raw winner  \
# 49   http://ufcstats.com/fighter-details/3cf18e01cb6cbde3      nc/nc    NaN
# 119  http://ufcstats.com/fighter-details/0e6b611451a9a7d8  draw/draw    NaN
# 130  http://ufcstats.com/fighter-details/e2be0c1a9b886d92  draw/draw    NaN
#
#      kd_1  kd_2  str_1  str_2  td_1  td_2  sub_1  sub_2  weight_class method  \
# 49      0     1      9     26     0     1      1      0     Flyweight    CNC
# 119     0     0    135     91     0     1      0      0  Catch Weight  M-DEC
# 130     0     0    147    112     1     1      0      0   Lightweight  M-DEC
#
#     method_detail  round  time
# 49            NaN      2  1:45
# 119           NaN      3  5:00
# 130           NaN      3  5:00

# %% [markdown]
# #### CONTEXT OF NULL VALUES
#
# ##### * NULL DETAILS - FIGHT WENT WITHOUT EXTRA REQ. DATA BESIDES ***-METHOD-***
# ##### * NULL WINNER  - FIGHT WENT DRAW/DRAW OR ARE NC/NC (NO CONTEST - fight occured but was stopped due to a fighter being fauled/injured or not passing tests)

# %% [markdown]
# # **EVENTS LIST**

# %%
fights_list = events[["event_name","event_date","fight_url"]].drop_duplicates()

fights_list.to_csv(r"C:\Git projects\ufc_ml\ufc_data\list_fights.csv", index=False)

fights_list
# Out:
#                                      event_name  event_date  \
# 0            UFC Fight Night: Fiziev vs. Torres  06/27/2026
# 1            UFC Fight Night: Fiziev vs. Torres  06/27/2026
# 2            UFC Fight Night: Fiziev vs. Torres  06/27/2026
# 3            UFC Fight Night: Fiziev vs. Torres  06/27/2026
# 4            UFC Fight Night: Fiziev vs. Torres  06/27/2026
# ...                                         ...         ...
# 1829  UFC Fight Night: Cannonier vs. Strickland  12/17/2022
# 1830  UFC Fight Night: Cannonier vs. Strickland  12/17/2022
# 1831  UFC Fight Night: Cannonier vs. Strickland  12/17/2022
# 1832  UFC Fight Night: Cannonier vs. Strickland  12/17/2022
# 1833  UFC Fight Night: Cannonier vs. Strickland  12/17/2022
#
#                                                fight_url
# 0     http://ufcstats.com/fight-details/c13dc0cccef263f7
# 1     http://ufcstats.com/fight-details/012c307c9d446c4d
# 2     http://ufcstats.com/fight-details/809814f03ff3140c
# 3     http://ufcstats.com/fight-details/81cde317c156723b
# 4     http://ufcstats.com/fight-details/d83294b031502177
# ...                                                  ...
# 1829  http://ufcstats.com/fight-details/ed6203e849a2bf28
# 1830  http://ufcstats.com/fight-details/efc64d8aae5628c9
# 1831  http://ufcstats.com/fight-details/8f00da6ea8186ce2
# 1832  http://ufcstats.com/fight-details/f87a7812733f7e8f
# 1833  http://ufcstats.com/fight-details/ccb7e2851319345d
#
# [1834 rows x 3 columns]

# %% [markdown]
# # **FIGHTERS LIST**

# %%
fighters = events[["fighter1","fighter1_url","fighter2","fighter2_url"]]

part1 = fighters[["fighter1", "fighter1_url"]].rename(
    columns={"fighter1": "fighter", "fighter1_url": "fighter_url"}
)

part2 = fighters[["fighter2", "fighter2_url"]].rename(
    columns={"fighter2": "fighter", "fighter2_url": "fighter_url"}
)

fighters = pd.concat([part1, part2], ignore_index=True)

fighters = fighters.drop_duplicates(ignore_index=True)

pd.set_option('display.max_colwidth', None)

fighters.to_csv(r"C:\Git projects\ufc_ml\ufc_data\list_fighters.csv", index=False)
(fighters)
# Out:
#                    fighter  \
# 0            Rafael Fiziev
# 1          Shara Magomedov
# 2           Matheus Camilo
# 3            Asu Almabayev
# 4          Ikram Aliskerov
# ..                     ...
# 938           Mauricio Rua
# 939          Mounir Lazzez
# 940    Shamil Abdurakhimov
# 941       Cheyanne Vlismas
# 942  Saidyokub Kakhramonov
#
#                                               fighter_url
# 0    http://ufcstats.com/fighter-details/c814b4c899793af6
# 1    http://ufcstats.com/fighter-details/06734ca9d88dec3a
# 2    http://ufcstats.com/fighter-details/72f890c5d421e705
# 3    http://ufcstats.com/fighter-details/8d3273573b85be09
# 4    http://ufcstats.com/fighter-details/b07aed698fba8624
# ..                                                    ...
# 938  http://ufcstats.com/fighter-details/140745cbbcb023ac
# 939  http://ufcstats.com/fighter-details/49ee5024966efc0d
# 940  http://ufcstats.com/fighter-details/2f5cbecbbe18bac4
# 941  http://ufcstats.com/fighter-details/4959f10a62f3fec3
# 942  http://ufcstats.com/fighter-details/50a28b9f8314e008
#
# [943 rows x 2 columns]
